# %%
import pandas as pd

# %%
df = pd.read_csv("wandb_export_2025-11-23T16_05_41.020+01_00.csv")
df
# Out:
#                                     Name     State Notes  User  \
# 0   Stanford_distilbert_partial_finetune  finished     -   NaN
# 1   Stanford_distilbert_partial_finetune  finished     -   NaN
# 2            Stanford_distilbert_lora_r8  finished     -   NaN
# 3            Stanford_distilbert_lora_r8  finished     -   NaN
# 4         Stanford_bert_partial_finetune  finished     -   NaN
# 5         Stanford_bert_partial_finetune  finished     -   NaN
# 6                  Stanford_bert_lora_r8  finished     -   NaN
# 7                  Stanford_bert_lora_r8  finished     -   NaN
# 8   Stanford_distilbert_partial_finetune  finished     -   NaN
# 9            Stanford_distilbert_lora_r8  finished     -   NaN
# 10        Stanford_bert_partial_finetune  finished     -   NaN
# 11                 Stanford_bert_lora_r8  finished     -   NaN
# 12                          experiment_1  finished     -   NaN
# 13  Stanford_distilbert_partial_finetune  finished     -   NaN
# ...
