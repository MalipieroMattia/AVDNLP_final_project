# %%
import pandas as pd

# %%
df = pd.read_csv("wandb_export_2025-11-30T20_02_06.351+01_00.csv")
df
# Out:
#                                      Name     State Notes  User  \
# 0   Stanford_deberta_xxl_partial_finetune  finished     -   NaN
# 1            Stanford_deberta_xxl_lora_r8  finished     -   NaN
# 2            Stanford_deberta_xxl_lora_r8   crashed     -   NaN
# 3            Stanford_deberta_xxl_lora_r8   crashed     -   NaN
# 4          Stanford_bert_partial_finetune  finished     -   NaN
# 5                   Stanford_bert_lora_r8  finished     -   NaN
# 6    Stanford_distilbert_partial_finetune  finished     -   NaN
# 7             Stanford_distilbert_lora_r8  finished     -   NaN
# 8          Stanford_bert_partial_finetune  finished     -   NaN
# 9                   Stanford_bert_lora_r8  finished     -   NaN
# 10         Stanford_bert_partial_finetune  finished     -   NaN
# 11                  Stanford_bert_lora_r8  finished     -   NaN
# 12         Stanford_bert_partial_finetune  finished     -   NaN
# 13                  Stanford_bert_lora_r8  finished     -   NaN
# ...

# %%
df.columns
# Out:
# Index(['Name', 'State', 'Notes', 'User', 'Tags', 'Created', 'Runtime', 'Sweep',
#        'accuracy/train', 'accuracy/val', 'epoch', 'learning_rate',
#        'loss/train', 'loss/val', 'test/acc', 'test/loss', 'train/acc',
#        'train/loss', 'val/acc', 'val/loss', 'data.data_dir', 'data.file_path',
#        'data.kaggle_dataset', 'data.label_map.contradiction',
#        'data.label_map.entailment', 'data.label_map.neutral', 'data.test_size',
#        'data.val_size', 'model.checkpoint_dir', 'model.distilbert',
#        'model.dropout_rate', 'model.freeze_strategy', 'model.lora.bias',
#        'model.lora.lora_alpha', 'model.lora.lora_dropout', 'model.lora.r',
#        'model.lora.target_modules', 'model.max_len', 'model.model_type',
#        'model.name', 'model.num_frozen_layers', 'model.save_local',
#        'model.use_lora', 'training.batch_size', 'training.dropout_rate',
#        'training.early_stopping_patience', 'training.learning_rate',
# ...
